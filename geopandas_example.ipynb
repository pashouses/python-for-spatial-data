# %%
import geopandas as gpd

# %%
indonesia_boundary = gpd.read_file('input/IDN.json')
indonesia_boundary.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GID_1      34 non-null     object
#  1   GID_0      34 non-null     object
#  2   COUNTRY    34 non-null     object
#  3   NAME_1     34 non-null     object
#  4   VARNAME_1  34 non-null     object
#  5   NL_NAME_1  34 non-null     object
#  6   TYPE_1     34 non-null     object
#  7   ENGTYPE_1  34 non-null     object
#  8   CC_1       34 non-null     object
#  9   HASC_1     34 non-null     object
#  10  ISO_1      34 non-null     object
#  11  geometry   34 non-null     geometry
# dtypes: geometry(1), object(11)
# memory usage: 3.3+ KB

# %%
indonesia_boundary.head()
# Out:
#        GID_1 GID_0    COUNTRY             NAME_1 VARNAME_1 NL_NAME_1  \
# 0    IDN.1_1   IDN  Indonesia               Aceh        NA        NA
# 1    IDN.2_1   IDN  Indonesia               Bali        NA        NA
# 2    IDN.3_1   IDN  Indonesia     BangkaBelitung        NA        NA
# 3    IDN.4_1   IDN  Indonesia             Banten        NA        NA
# 4    IDN.5_1   IDN  Indonesia           Bengkulu        NA        NA
# 5    IDN.6_1   IDN  Indonesia          Gorontalo        NA        NA
# 6    IDN.7_1   IDN  Indonesia        JakartaRaya        NA        NA
# 7    IDN.8_1   IDN  Indonesia              Jambi        NA        NA
# 8    IDN.9_1   IDN  Indonesia          JawaBarat        NA        NA
# 9   IDN.10_1   IDN  Indonesia         JawaTengah        NA        NA
# 10  IDN.11_1   IDN  Indonesia          JawaTimur        NA        NA
# 11  IDN.12_1   IDN  Indonesia    KalimantanBarat        NA        NA
# 12  IDN.13_1   IDN  Indonesia  KalimantanSelatan        NA        NA
# 13  IDN.14_1   IDN  Indonesia   KalimantanTengah        NA        NA
# 14  IDN.34_1   IDN  Indonesia    KalimantanTimur        NA        NA
# 15  IDN.35_1   IDN  Indonesia    KalimantanUtara        NA        NA
# 16  IDN.16_1   IDN  Indonesia      KepulauanRiau        NA        NA
# 17  IDN.17_1   IDN  Indonesia            Lampung        NA        NA
# 18  IDN.19_1   IDN  Indonesia             Maluku        NA        NA
# 19  IDN.18_1   IDN  Indonesia        MalukuUtara        NA        NA
# 20  IDN.20_1   IDN  Indonesia  NusaTenggaraBarat        NA        NA
# 21  IDN.21_1   IDN  Indonesia  NusaTenggaraTimur        NA        NA
# 22  IDN.23_1   IDN  Indonesia              Papua        NA        NA
# 23  IDN.22_1   IDN  Indonesia         PapuaBarat        NA        NA
# 24  IDN.24_1   IDN  Indonesia               Riau        NA        NA
# 25  IDN.25_1   IDN  Indonesia      SulawesiBarat        NA        NA
# 26  IDN.26_1   IDN  Indonesia    SulawesiSelatan        NA        NA
# 27  IDN.27_1   IDN  Indonesia     SulawesiTengah        NA        NA
# 28  IDN.28_1   IDN  Indonesia   SulawesiTenggara        NA        NA
# 29  IDN.29_1   IDN  Indonesia      SulawesiUtara        NA        NA
#
#        TYPE_1 ENGTYPE_1 CC_1 HASC_1  ISO_1  \
# 0   Propinisi  Province   11  ID.AC  ID-AC
# 1   Propinisi  Province   51  ID.BA  ID-BA
# 2   Propinisi  Province   19  ID.BB     NA
# 3   Propinisi  Province   36  ID.BT  ID-BT
# 4   Propinisi  Province   17  ID.BE  ID-BE
# 5   Propinisi  Province   75  ID.GO  ID-GO
# 6   Propinisi  Province   31  ID.JK  ID-JK
# 7   Propinisi  Province   15  ID.JA  ID-JA
# 8   Propinisi  Province   32  ID.JR  ID-JB
# 9   Propinisi  Province   33  ID.JT  ID-JT
# 10  Propinisi  Province   35  ID.JI  ID-JI
# 11  Propinisi  Province   61  ID.KB  ID-KB
# 12  Propinisi  Province   63  ID.KS  ID-KS
# 13  Propinisi  Province   62  ID.KT  ID-KT
# 14  Propinisi  Province   64  ID.KM  ID-KI
# 15  Propinisi  Province   64  ID.KU  ID-KU
# 16  Propinisi  Province   21  ID.KR  ID-KR
# 17  Propinisi  Province   18  ID.LA  ID-LA
# 18  Propinisi  Province   81  ID.MA  ID-ML
# 19  Propinisi  Province   82  ID.MU  ID-MU
# 20  Propinisi  Province   52  ID.NB  ID-NB
# 21  Propinisi  Province   53  ID.NT  ID-NT
# 22  Propinisi  Province   94  ID.PA  ID-PP
# 23  Propinisi  Province   91  ID.IB  ID-PB
# 24  Propinisi  Province   14  ID.RI  ID-RI
# 25  Propinisi  Province   76  ID.SR  ID-SR
# 26  Propinisi  Province   73  ID.SE  ID-SN
# 27  Propinisi  Province   72  ID.ST  ID-ST
# 28  Propinisi  Province   74  ID.SG  ID-SG
# 29  Propinisi  Province   71  ID.SW  ID-SA
#
#                                              geometry
# 0   MULTIPOLYGON (((96.68130 2.09740, 96.68720 2.0...
# 1   MULTIPOLYGON (((115.52570 -8.80450, 115.52540 ...
# 2   MULTIPOLYGON (((108.01370 -3.24450, 108.01080 ...
# 3   MULTIPOLYGON (((106.38680 -6.99070, 106.38500 ...
# 4   MULTIPOLYGON (((103.57300 -4.92300, 103.57130 ...
# 5   MULTIPOLYGON (((123.54910 0.43250, 123.53990 0...
# 6   MULTIPOLYGON (((106.86720 -6.35460, 106.86220 ...
# 7   MULTIPOLYGON (((101.87180 -2.72920, 101.86320 ...
# 8   MULTIPOLYGON (((108.13310 -7.78340, 108.08960 ...
# 9   MULTIPOLYGON (((110.00440 -7.88540, 110.00250 ...
# 10  MULTIPOLYGON (((110.91760 -8.21910, 110.91750 ...
# 11  MULTIPOLYGON (((110.20290 -3.06490, 110.20450 ...
# 12  MULTIPOLYGON (((116.15360 -2.99070, 116.16790 ...
# 13  MULTIPOLYGON (((111.79320 -3.52580, 111.77920 ...
# 14  MULTIPOLYGON (((117.85590 1.97530, 117.85840 1...
# 15  MULTIPOLYGON (((116.82360 2.73080, 116.82170 2...
# 16  MULTIPOLYGON (((105.25350 -1.29510, 105.25030 ...
# 17  MULTIPOLYGON (((104.56410 -5.60180, 104.58930 ...
# 18  MULTIPOLYGON (((130.91830 -8.25620, 130.91690 ...
# 19  MULTIPOLYGON (((124.44790 -2.04010, 124.44790 ...
# 20  MULTIPOLYGON (((119.20060 -8.58110, 119.20070 ...
# 21  MULTIPOLYGON (((122.88150 -10.97740, 122.88560...
# 22  MULTIPOLYGON (((138.89110 -8.01300, 138.89250 ...
# 23  MULTIPOLYGON (((132.90520 -4.12950, 132.90330 ...
# 24  MULTIPOLYGON (((102.37660 -1.02770, 102.35430 ...
# 25  MULTIPOLYGON (((118.99600 -3.54990, 118.99530 ...
# 26  MULTIPOLYGON (((117.20250 -7.75850, 117.20100 ...
# 27  MULTIPOLYGON (((123.60910 -1.68230, 123.61140 ...
# 28  MULTIPOLYGON (((122.71790 -6.20290, 122.72310 ...
# 29  MULTIPOLYGON (((123.58080 0.31450, 123.57560 0...

# %%
indonesia_boundary.plot()
# Out:
# <Axes: >
